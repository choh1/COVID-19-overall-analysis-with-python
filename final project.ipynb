# %%
#import necessary libraries for the project 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data

d1 = pd.read_csv("~/Downloads/daily.csv")

#COVID19 data in US
#https://covidtracking.com/data/download
#https://data.cdc.gov/NCHS/Deaths-involving-coronavirus-disease-2019-COVID-19/ks3g-spdg

# %%
#peak at the data 

d1.head()
# Out:
#        date  states  positive  negative  pending  hospitalizedCurrently  \
# 0  20200720      56   3813916  42655608   3003.0                58330.0
# 1  20200719      56   3755968  41978359   3052.0                57790.0
# 2  20200718      56   3692061  41273443   3032.0                57559.0
# 3  20200717      56   3626881  40576852   3002.0                57705.0
# 4  20200716      56   3549648  39802297   2929.0                57369.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                279030.0          6558.0          12475.0
# 1                277378.0          6391.0          12391.0
# 2                276439.0          6396.0          12342.0
# 3                274436.0          6453.0          12243.0
# 4                271758.0          6359.0          12091.0
#
#    onVentilatorCurrently  ...          lastModified     total  \
# 0                 2403.0  ...  2020-07-20T00:00:00Z  46472527
# ...

# %%
#import data
d2 = pd.read_csv("~/Downloads/Deaths_COVID19.csv")

# %%
#peak at the data

d2.head()
# Out:
#    Data as of  Start week    End Week          State Age group  \
# 0  07/15/2020  02/01/2020  07/11/2020  United States  All Ages
# 1  07/15/2020  02/01/2020  07/11/2020  United States  All Ages
# 2  07/15/2020  02/01/2020  07/11/2020  United States  All Ages
# 3  07/15/2020  02/01/2020  07/11/2020  United States  All Ages
# 4  07/15/2020  02/01/2020  07/11/2020  United States  All Ages
#
#                   Race and Hispanic Origin Group  COVID-19 Deaths  \
# 0                                   Total Deaths         121374.0
# 1                             Non-Hispanic White          64073.0
# 2                             Non-Hispanic Black          27848.0
# 3  Non-Hispanic American Indian or Alaska Native            974.0
# 4                             Non-Hispanic Asian           6022.0
#
#    Total Deaths  Pneumonia Deaths  Pneumonia and COVID-19 Deaths  \
# 0     1387325.0          131332.0                        52431.0
# ...

# %%
#look at columns
d1.columns
# Out:
# Index(['date', 'states', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'dateChecked', 'death', 'hospitalized', 'lastModified',
#        'total', 'totalTestResults', 'posNeg', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease', 'hash'],
#       dtype='object')

# %%
#look at columns
d2.columns
# Out:
# Index(['Data as of', 'Start week', 'End Week', 'State', 'Age group',
#        'Race and Hispanic Origin Group', 'COVID-19 Deaths', 'Total Deaths',
#        'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths', 'Influenza Deaths',
#        'Pneumonia, Influenza, or COVID-19 Deaths', 'Footnote'],
#       dtype='object')

# %%
#view description of the data
display(d1.describe())
display(d1.head())
display(d1.info())
# Out:
#                date      states      positive      negative       pending  \
# count  1.810000e+02  181.000000  1.810000e+02  1.810000e+02    139.000000
# mean   2.020043e+07   42.480663  1.079665e+06  9.904412e+06   8393.000000
# std    1.750595e+02   23.178676  1.111916e+06  1.243087e+07  15473.604512
# min    2.020012e+07    1.000000  2.000000e+00  0.000000e+00    103.000000
# 25%    2.020031e+07   50.000000  1.271000e+03  2.867000e+03   1904.500000
# 50%    2.020042e+07   56.000000  8.132660e+05  3.395710e+06   2812.000000
# 75%    2.020060e+07   56.000000  1.900441e+06  1.741710e+07   4137.500000
# max    2.020072e+07   56.000000  3.813916e+06  4.265561e+07  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count             126.000000              139.000000      117.000000
# mean            38274.380952           142614.496403     8489.435897
# std             15794.784795            93759.520502     3631.506791
# ...

# %%
#view description of the data
display(d2.describe())
display(d2.head())
display(d2.info())
# Out:
#        COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# count      3794.000000  3.206000e+03       3606.000000
# mean        127.274381  1.732911e+03        145.209651
# std        2390.567177  3.193086e+04       2754.308200
# min           0.000000  0.000000e+00          0.000000
# 25%           0.000000  0.000000e+00          0.000000
# 50%           0.000000  2.100000e+01          0.000000
# 75%           0.000000  1.577500e+02          0.000000
# max      121374.000000  1.387325e+06     131332.000000
#
#        Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# count                    3950.000000       4005.000000
# mean                       52.546582          6.064669
# std                      1000.238338        129.160010
# min                         0.000000          0.000000
# 25%                         0.000000          0.000000
# 50%                         0.000000          0.000000
# 75%                         0.000000          0.000000
# ...

# %%
    #data processing:
#getting rid of spaces in the column names by renaming the names
d2.columns = [c.replace(' ', '_') for c in d2.columns]
d2.head()

#rename columns
d2.rename(columns= {'Data_as_of':'date','Start_week':'start','End_week':'end',
                    'State':'state','Age_group':'age', 'Race_and_Hispanic_Origin_Group':'race',
                    'COVID-19_Deaths':'covid_deaths','Total_Deaths':'total_deaths',
                    'Pneumonia_Deaths':'pneumonia_d','Pneumonia_and_COVID-19_Deaths':'pneumonia_covid_d',
                   'Influenza_Deaths':'influenza_d', 'Pneumonia,_Influenza,_or_COVID-19_Deaths':'pneumonia_influenza_covid_d',
                   'Footnote':'note'})
# Out:
#             date       start    End_Week          state                age  \
# 0     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# 1     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# 2     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# 3     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# 4     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# ...          ...         ...         ...            ...                ...
# 4756  07/15/2020  02/01/2020  07/11/2020    Puerto Rico        45-54 years
# 4757  07/15/2020  02/01/2020  07/11/2020    Puerto Rico        55-64 years
# 4758  07/15/2020  02/01/2020  07/11/2020    Puerto Rico        65-74 years
# 4759  07/15/2020  02/01/2020  07/11/2020    Puerto Rico        75-84 years
# 4760  07/15/2020  02/01/2020  07/11/2020    Puerto Rico  85 years and over
#
#                                                race  covid_deaths  \
# ...

# %%
#check all null values
d2.isnull().sum()

#fill missing values with 0
d2.fillna(0)
# Out:
#       Data_as_of  Start_week    End_Week          State          Age_group  \
# 0     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# 1     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# 2     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# 3     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# 4     07/15/2020  02/01/2020  07/11/2020  United States           All Ages
# ...          ...         ...         ...            ...                ...
# 4756  07/15/2020  02/01/2020  07/11/2020    Puerto Rico        45-54 years
# 4757  07/15/2020  02/01/2020  07/11/2020    Puerto Rico        55-64 years
# 4758  07/15/2020  02/01/2020  07/11/2020    Puerto Rico        65-74 years
# 4759  07/15/2020  02/01/2020  07/11/2020    Puerto Rico        75-84 years
# 4760  07/15/2020  02/01/2020  07/11/2020    Puerto Rico  85 years and over
#
# ...

# %%
#check all null values
d1.isnull().sum()
# Out:
# date                         0
# states                       0
# positive                     0
# negative                     0
# pending                     42
# hospitalizedCurrently       55
# hospitalizedCumulative      42
# inIcuCurrently              64
# inIcuCumulative             63
# onVentilatorCurrently       63
# onVentilatorCumulative      70
# recovered                   63
# dateChecked                  0
# death                       35
# hospitalized                42
# lastModified                 0
# total                        0
# totalTestResults             0
# posNeg                       0
# deathIncrease                0
# hospitalizedIncrease         0
# negativeIncrease             0
# positiveIncrease             0
# totalTestResultsIncrease     0
# hash                         0
# total active                63
# dtype: int64

# %%
d2.columns
# Out:
# Index(['Data_as_of', 'Start_week', 'End_Week', 'State', 'Age_group',
#        'Race_and_Hispanic_Origin_Group', 'COVID-19_Deaths', 'Total_Deaths',
#        'Pneumonia_Deaths', 'Pneumonia_and_COVID-19_Deaths', 'Influenza_Deaths',
#        'Pneumonia,_Influenza,_or_COVID-19_Deaths', 'Footnote'],
#       dtype='object')

# %%
d1['total active'] = d1['totalTestResults']-(d1['death']+d1['recovered'])
total_active= d1['total active'].sum
print('The total number of active covid-19 cases in US:', total_active )
# Out:
# The total number of active covid-19 cases in US: <bound method Series.sum of 0      45176154.0
# 1      44470288.0
# 2      43710389.0
# 3      42965366.0
# 4      42130728.0
#           ...
# 176           NaN
# 177           NaN
# 178           NaN
# 179           NaN
# 180           NaN
# Name: total active, Length: 181, dtype: float64>

# %%
#filter the dataset
d1.groupby(['date'])['states','positive','negative',
                    'recovered','death','deathIncrease',
                    'hospitalized','totalTestResults'].max()
# Out:
# /Users/hanacho/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#           states  positive  negative  recovered     death  deathIncrease  \
# date
# 20200122       1         2         0        NaN       NaN              0
# 20200123       1         2         0        NaN       NaN              0
# 20200124       1         2         0        NaN       NaN              0
# 20200125       1         2         0        NaN       NaN              0
# 20200126       1         2         0        NaN       NaN              0
# ...          ...       ...       ...        ...       ...            ...
# 20200716      56   3549648  39802297  1090645.0  130572.0            974
# 20200717      56   3626881  40576852  1106844.0  131523.0            951
# 20200718      56   3692061  41273443  1122720.0  132395.0            872
# ...

# %%
#value counts
d1.positive.value_counts()
# Out:
# 2          7
# 3          3
# 13         2
# 8          2
# 18         2
#           ..
# 26025      1
# 133540     1
# 2786467    1
# 3350434    1
# 1773902    1
# Name: positive, Length: 170, dtype: int64

# %% [markdown]
# # Visualization

# %%
#A relationship between patients who were tested for postive of COVID-19 and
#who were recovered from COVID-19

sns.relplot(x="positive", y="recovered",data=d1)

#for the initial 1,000,000 number of patients who were had positive test results for COVID-19, 
#there are less than 200,000 recovered. However, as the number grew for positive tests,
#more than 1,200,000 patients has recovered from the disease.
#There is a linear relationship. It can be concluded that people are recovering.

# %%
#A relationship for the total people who had been tested
#and had positive result for COVID-19.

sns.relplot(x="totalTestResults", y="positive", data=d1)

#Out of the total number of test cases are 4e7, more than 4,000,000 people has been tested for postitive.

# %%
sns.relplot(x="death", y="positive", 
            data=d1,
            hue="recovered")   #hue shows recovered patients who were tested for postive COVID-19
#It explains that as people are tested with positive, the number of death increases correspondingly.
#However, as the number of death increases, patients being recovered is also increasing.

# %%
#relationships between the variables 
sns.pairplot(d1)

# %%
sns.relplot(x ='Age_group',
            y ='COVID-19_Deaths', 
            kind='line',  #draw a line graph
            data = d2)

# %%
#categorical data plot
sns.catplot(x='Age_group',
           y='COVID-19_Deaths',
           data=d2)

#The plot indicates that as the age becomes older, the number of deaths increases correspondingly. 
#The number is greatest for age groups of all ages.

# %%
d1.plot()

# %%
d2.plot()

# %%
#install plotly
pip install plotly==4.9.0
# Out:
#   File "<ipython-input-22-d4f9ce914d67>", line 2
#     pip install plotly==4.9.0
#               ^
# SyntaxError: invalid syntax

# %%
#import libraries

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

#import folium

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

import math
import random
from datetime import timedelta



#color pallette 
cnf='#393e46'
dth='#ff2e63'
rec='#21bf73'
act='#fe9801'

# %%
#piechart for race distribution
plt.figure(figsize=(10,10))
d2['Race_and_Hispanic_Origin_Group'].value_counts().plot.pie(autopct="%1.1f%%")
#plt.axis('equal')
plt.show()

# %%
sns.set()
d1.info()
plt.figure(figsize=(15,5))
sns.barplot(data=d1, x="positive", y="deathIncrease", ci="sd")

#people being tested for postive continuously increases, but actual number of death is treanding downward.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      181 non-null    int64
#  1   states                    181 non-null    int64
#  2   positive                  181 non-null    int64
#  3   negative                  181 non-null    int64
#  4   pending                   139 non-null    float64
#  5   hospitalizedCurrently     126 non-null    float64
#  6   hospitalizedCumulative    139 non-null    float64
#  7   inIcuCurrently            117 non-null    float64
#  8   inIcuCumulative           118 non-null    float64
#  9   onVentilatorCurrently     118 non-null    float64
#  10  onVentilatorCumulative    111 non-null    float64
#  11  recovered                 118 non-null    float64
#  12  dateChecked               181 non-null    object
# ...

# %%
#pointplot

plt.figure(figsize=(20,5))
sns.pointplot(data=d1,x="positive", y="hospitalized", ci="sd")

#patients being hospitalized also increases accordingly

# %%
#barplot

plt.figure(figsize=(20,5))
sns.barplot(data=d2,x="Age_group", y="COVID-19_Deaths", ci="sd")

#deaths increases as the age increases beyond 35-44years group, 
#and is the greatest in a group of 85 years and over.

# %%
plt.figure(figsize=(15,5))

sns.boxenplot(data=d2,
              x="Age_group",y="COVID-19_Deaths")

#among the people tested with positive, number of death also increases accordingly.

# %%
plt.figure(figsize=(15,5))
sns.regplot(data=d1,x="date", y="recovered")

#as time goes by, number of recovered patients also lies in increasing trend.

# %%
#Death by states, showing with the age group
import plotly.express as px

fig=px.bar(d2, x="State",y="COVID-19_Deaths",
           color="Age_group",orientation="v",
           height=600,
          title="COVID-19 Death by States",
           color_discrete_sequence=px.colors.cyclical.mygbm)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d4881e8167ad> in <module>
#       2 import plotly.express as px
#       3
# ----> 4 fig=px.bar(d2, x="State",y="COVID-19_Deaths",
#       5            color="Age_group",orientation="v",
#       6            height=600,
#
# NameError: name 'd2' is not defined
